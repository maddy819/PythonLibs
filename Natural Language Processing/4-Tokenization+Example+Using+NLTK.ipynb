# %%
##  Tokenization
## Sentence-->paragraphs
import nltk
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.tokenize import wordpunct_tokenize
from nltk.tokenize import TreebankWordTokenizer
# nltk.download('punkt')
# nltk.download('punkt_tab')

# %%
# A Paragraph / Document of text data is called as Corpus
corpus="""Hello Welcome,to Krish Naik's NLP Tutorials.
Please do watch the entire course! to become expert in NLP.
"""

print(corpus)
# Out:
# Hello Welcome,to Krish Naik's NLP Tutorials.
# Please do watch the entire course! to become expert in NLP.

# %%
# Sentence Tokenization
documents=sent_tokenize(corpus)

print(type(documents))
print(documents)

for sentence in documents:
    print(sentence)
# Out:
# <class 'list'>
# ["Hello Welcome,to Krish Naik's NLP Tutorials.", 'Please do watch the entire course!', 'to become expert in NLP.']
# Hello Welcome,to Krish Naik's NLP Tutorials.
# Please do watch the entire course!
# to become expert in NLP.

# %%
# Word Tokenization
print("\nWord Tokenization\n")
print(word_tokenize(corpus))
# Out:
# Word Tokenization
#
# ['Hello', 'Welcome', ',', 'to', 'Krish', 'Naik', "'s", 'NLP', 'Tutorials', '.', 'Please', 'do', 'watch', 'the', 'entire', 'course', '!', 'to', 'become', 'expert', 'in', 'NLP', '.']

# %%
# Word Tokenization for each sentence
print("\nWord Tokenization for each sentence\n")
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# Word Tokenization for each sentence
#
# ['Hello', 'Welcome', ',', 'to', 'Krish', 'Naik', "'s", 'NLP', 'Tutorials', '.']
# ['Please', 'do', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
# WordPunct Tokenization
# It splits all punctuations into separate tokens
print("\nWordPunct Tokenization\n")
print(wordpunct_tokenize(corpus))
# Out:
# WordPunct Tokenization
#
# ['Hello', 'Welcome', ',', 'to', 'Krish', 'Naik', "'", 's', 'NLP', 'Tutorials', '.', 'Please', 'do', 'watch', 'the', 'entire', 'course', '!', 'to', 'become', 'expert', 'in', 'NLP', '.']

# %%
# TreebankWordTokenizer
# It is similar to WordPunct but it does not split 's and n't
tokenizer=TreebankWordTokenizer()

print("\nTreebankWordTokenizer\n")
print(tokenizer.tokenize(corpus))
# Out:
# TreebankWordTokenizer
#
# ['Hello', 'Welcome', ',', 'to', 'Krish', 'Naik', "'s", 'NLP', 'Tutorials.', 'Please', 'do', 'watch', 'the', 'entire', 'course', '!', 'to', 'become', 'expert', 'in', 'NLP', '.']
