# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Example with predefined data
x = [1, 2, 3, 4, 5]
y = [2, 11, 5, 7, 6]

plt.plot(x, y, marker='o')
plt.title("Line Chart")
plt.show()

# %%
# Additional example with random data generated using numpy
x = np.arange(25)
y = np.random.randint(1, 50, size=25)

plt.plot(x, y, marker='s')
plt.title("Line Chart")
plt.show()

# %%
# Another example with multiple points of y axis for same x axis value using numpy

# Set random seed for reproducibility
# This is important for generating the same random numbers across different runs
x = np.arange(1,6)
y = np.random.randint(1, 500, size=(5, 6)) # 5 rows (x values), 6 columns (y values)
# Shuffle rows
rows = np.random.permutation(y.shape[0])

# Shuffle columns
cols = np.random.permutation(y.shape[1])

shuffled = y[rows][:, cols]

print("x:", x)
print("y:\n", shuffled)

plt.figure(figsize=(6,4))
for col in range(shuffled.shape[1]):
    print(f"Plotting column {col} with values {shuffled[:,col]}")
    plt.plot(x, shuffled[:,col], marker='o')  # marker only

#plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Multiple y values per x (2D array)')
plt.legend()
plt.show()
# Out:
# x: [1 2 3 4 5]
# y:
#  [[354 151  86 161 451 232]
#  [137 325 243 180 340 150]
#  [418 470 499 377 288 185]
#  [273 279 334 313 393 416]
#  [ 50 491 222  29 395 274]]
# Plotting column 0 with values [354 137 418 273  50]
# Plotting column 1 with values [151 325 470 279 491]
# Plotting column 2 with values [ 86 243 499 334 222]
# Plotting column 3 with values [161 180 377 313  29]
# Plotting column 4 with values [451 340 288 393 395]
# Plotting column 5 with values [232 150 185 416 274]
# C:\Users\vicky\AppData\Local\Temp\ipykernel_23508\1290750922.py:27: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Example to show sales per dayof week
days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
sales = [150, 200, 300, 250, 400, 500, 450]

plt.plot(days, sales, marker='o')
plt.title("Sales per Day of Week")
plt.xlabel("Day of Week")
plt.ylabel("Sales")
plt.grid()
plt.show()
